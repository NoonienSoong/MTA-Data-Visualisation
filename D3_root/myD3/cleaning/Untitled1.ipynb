# %%
import pandas as pd


bob = pd.ExcelFile('/Users/nicholasjackson/Downloads/DetailedStateInfoAP-CS-A-2006-2013-with-PercentBlackAndHIspanicByState-fixed.xlsx')

# %%
bob.sheet_names
# Out:
# [u'Sheet1', u'Sheet2', u'Sheet4']

# %%
df = bob.parse('Sheet1')
df.iloc[[1,2,4],[1]]

# %%
df
# Out:
#    Please note that the College Board doesn't report scores if the total in a category is less than 5, so if there are less than 5 people in a category we don't know how many passed  \
# 0                                                 NaN
# 1                               National Data - CS A
# 2                                                 NaN
# 3                                                2006
# 4                                                2007
# 5                                                2008
# 6                                                2009
# 7                                                2010
# 8                                                2011
# 9                                                2012
# 10                                               2013
# 11                                                NaN
# 12                       National Data - Calculus AB
# 13                                                NaN
# ...

# %%
z= np.random.normal(1,100,14
                    )
z
# Out:
# array([  77.91522785,   56.77687349,  -48.30027521,   47.44549489,
#          10.63093641,  -65.45337303,  133.37558861,  -40.70581323,
#          77.71298246,  -62.14598597,   53.03279607, -156.73134672,
#        -170.83238219, -132.05227861])

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline



def sigma(x):
    y = (3.5*np.std(x))/(len(x)) ** 1/3
    
    return y
bins = sigma(z)
plt.hist(z,bins,normed=True)
# Out:
# (array([ 0.00493084,  0.        ,  0.00657445,  0.        ,  0.00164361,
#          0.00821806,  0.00164361]),
#  array([-170.83238219, -127.37410064,  -83.9158191 ,  -40.45753756,
#            3.00074398,   46.45902552,   89.91730706,  133.37558861]),
#  <a list of 7 Patch objects>)

# %%
from webmap.mapper import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-f569cce55152> in <module>()
# ----> 1 from webmap.mapper import *
#
# ImportError: No module named webmap.mapper
